# %% [markdown]
# # Week 1

# %% [markdown]
# <img src="screen.png" width="600">

# %% [markdown]
# Week 1 was busy. We dove right into the fast lane and covered a lot of material.
#
# * Git and Github
# * Unix workflow
# * Basic GUI
# * More Python OOP
#  * Magic Methods
#  * Inheritance
# * SQL and RDBMS schemae
#  * Postgresql
#  * psycopg2
# * Imperative vs. Descriptive scripting
# * Pandas
# * Matplotlib

# %% [markdown]
# Major takeaways from this week include:
# * Understanding Git is crucial
# * I have to let go of thinking that I can complete the projects in the given time and just do as much as I can
# * My code is sloppy and my Python skills are weak
# * Every job interview will include SQL, and I need a lot more practice
# * Developing basic computer science undersatnding will go a long way
# * Spending some time learning to use my text editor more efficiently will make EVERYTHING faster
#
# The "matplotlib_pandas" notebook has some work from this week.

# %% [markdown]
# Each day we have two lectures and two programming sessions. One programming session is individual and the other is done in pairs which change each day. There is so much material that we never get through it all. The upside of this is that I will have many more resources to study after the 13 weeks. One challenge is knowing how much is enough. We have our first assessment on Monday of week two, so we should get some clarity after that. We also got introduced to career services, web development students, and the Galvanize experience in general.

# %% [markdown]
# I realized on Saturday that I went overboard with what I took on in my first full week. In addition to starting this very intense program, I jumped right back into a full workout schedule after not have worked out in two weeks. The cumulative stress took its toll on Friday night when I didn't sleep well and Saturday when I felt like a zombie all day. It's Sunday and I'm feeling a little better, like I'm on my way to feeling normal again. I wish I could do this program with full effort, lift weights three times a week, and bike to work every day. My body is telling me that I can't.

# %% [markdown]
# For many of the assignments we were given starter code and asked to fill it in. This was helpful for understanding conventions fomatting, and style. Here are some examples of code we wrote:
#
# ```python
#
# #!/usr/bin/env python
# # -*- coding: utf-8 -*-
#
# import math
#
# class Circle():
#     """A circular shape as defined by a center point and radius.
#     This shape is designed to be drawn using SimpleGUI (see simplegui.py).
#
#     Parameters
#     ----------
#     cx      : {int} x coordinate of the center point
#     cy      : {int} y coordinate of the center point
#     radius  : {int} radius of the circle
#     color   : {tuple} of (r,g,b) coordinates
#     """
#     def __init__(self, cx, cy, radius, color):
#         """Constructs a Circle instance
#         centered around (cx,cy) with given radius and color.
#         """
#         self.cx = cx
#         self.cy = cy
#         self.radius = radius
#         self.color = color
#
#     def mu(self, x, y):
#         """Characteristic function of the shape.
#         Returns True if (x,y) is inside the shape, else False.
#
#         Parameters
#         ----------
#         x : {int} x coordinate of a pixel
#         y : {int} y coordinate of a pixel
#
#         Returns
#         -------
#         bool : True or False whether (x,y) is within the shape.
#         """
#         t_dist = math.sqrt((x - self.cx)**2 + (y - self.cy)**2)
#         return (t_dist < self.radius)
#
#
# class Rectangle():
#     """A rectangular shape as defined by two extreme pixels points
#     (one upper-left, one lower-right).
#     This shape is designed to be drawn using SimpleGUI (see simplegui.py).
#
#     Parameters
#     ----------
#     x0      : {int} x coordinate of the top-left point
#     y0      : {int} y coordinate of the top-left point
#     x1      : {int} x coordinate of the bottom-right point
#     y1      : {int} y coordinate of the bottom-right point
#     color   : {tuple} of (r,g,b) coordinates
#     """
#     def __init__(self, x0, y0, x1, y1, color):
#         """Constructs a Rectangle instance
#         with top-left point (x0,y0), bottom-right (x1,y1) and color.
#         """
#         self.x0 = x0
#         self.y0 = y0
#         self.x1 = x1
#         self.y1 = y1
#         self.color = color
#
#     def mu(self, x, y):
#         """Characteristic function of the shape.
#         Returns True if (x,y) is inside the shape, else False.
#
#         Parameters
#         ----------
#         x : {int} x coordinate of a pixel
#         y : {int} y coordinate of a pixel
#
#         Returns
#         -------
#         bool : True or False whether (x,y) is within the shape.
#         """
#         return self.x0 < x < self.x1 and self.y0 < y < self.y1
#
#
# #!/usr/bin/env python
# # -*- coding: utf-8 -*-
#
# class UnionShape():
#     """The union of two shapes (as objects defined in shapes.py).
#
#     Parameters
#     ----------
#     shape_a   : {shape} shape object A.
#     shape_b   : {shape} shape object B.
#
#     Attributes
#     ----------
#     TBD
#     """
#     def __init__(self, shape_a, shape_b):
#         """Constructs a UnionShape as union of given shapes
#         shape_a and shape_b.
#
#         Note: color on union should be the average between
#         colors of shape_a and shape_b.
#         """
#         self.shape_a = shape_a
#         self.shape_b = shape_b
#         self.color = []
#         for item in list(zip(shape_a.color, shape_b.color)):
#             self.color.append(int(sum(item)/2))
#         self.color = tuple(self.color)
#
#     def mu(self, x, y):
#         """Characteristic function of the shape.
#         Returns True if (x,y) is inside the shape, else False.
#
#         Parameters
#         ----------
#         x : int, x coordinate of a pixel
#         y : int, y coordinate of a pixel
#
#         Returns
#         -------
#         boolean : True or False whether (x,y) is within the shape.
#         """
#         # if shape_a(x,y) == True and shape_b(x,y) == True:
#         #     return True
#         return self.shape_a.mu(x,y) == True or self.shape_b.mu(x,y) == True
#
#
# class IntersectionShape():
#     """The intersection of two shapes (as objects defined in shapes.py).
#
#     Parameters
#     ----------
#     shape_a   : {shape} shape object A.
#     shape_b   : {shape} shape object B.
#
#     Attributes
#     ----------
#     TBD
#     """
#     def __init__(self, shape_a, shape_b):
#         """Constructs a IntersectionShape as intersection
#         of given shapes shape_a and shape_b.
#
#         Note: color or intersection should be the average between
#         colors of shape_a and shape_b.
#         """
#         self.shape_a = shape_a
#         self.shape_b = shape_b
#         self.color = []
#         for item in list(zip(shape_a.color, shape_b.color)):
#             self.color.append(int(sum(item)/2))
#         self.color = tuple(self.color)
#
#     def mu(self, x, y):
#         """Characteristic function of the shape.
#         Returns True if (x,y) is inside the shape, else False.
#
#         Parameters
#         ----------
#         x : int, x coordinate of a pixel
#         y : int, y coordinate of a pixel
#
#         Returns
#         -------
#         boolean : True or False whether (x,y) is within the shape.
#         """
#         return self.shape_a.mu(x,y) == True and self.shape_b.mu(x,y) == True
#
#
# class DiffShape():
#     """The difference of two shapes (as objects defined in shapes.py).
#
#     Parameters
#     ----------
#     shape_a   : {shape} shape object A.
#     shape_b   : {shape} shape object B.
#
#     Attributes
#     ----------
#     TBD
#     """
#     def __init__(self, shape_a, shape_b):
#         """Constructs a DiffShape as difference between two given shapes
#         shape_a and shape_b.
#
#         Note: color or difference should be the color of shape_a.
#         """
#         self.shape_a = shape_a
#         self.shape_b = shape_b
#         self.color = shape_a.color
#
#     def mu(self, x, y):
#         """Characteristic function of the shape.
#         Returns True if (x,y) is inside the shape, else False.
#
#         Parameters
#         ----------
#         x : int, x coordinate of a pixel
#         y : int, y coordinate of a pixel
#
#         Returns
#         -------
#         boolean : True or False whether (x,y) is within the shape.
#         """
#         return self.shape_a.mu(x,y) == True and self.shape_b.mu(x,y) == False
#
#
#
# ```

# %% [markdown]
# ```sql
#
# select userid, number_of_reg
# from registrations as r1
#     inner join
#         (select tmstmp::date as date,
#                 count(userid) as number_of_reg
#         from    registrations
#         group by date) as r2
#     on r2.date = r1.tmstmp::date;
#
# select  tg.userid ,
#         tg.grp ,
#         t2.mobile_logins ,
#         t2.web_logins
# from    test_group as tg
#         inner join
#
#             (select l.userid,
#             sum(case when l.type = ‘mobile’ then 1 else 0 end)
#             as mobile_logins,
#             sum(case when l.type = ‘web’ then 1 else 0 end)
#             as web_logins
# from logins as l
# group by l.userid
# having sum(case when l.type = ‘mobile’ then 1 else 0 end)  >
#    sum(case when l.type = ‘web’ then 1 else 0 end)) as t2
#
# on tg.userid = t2.userid
# where tg.grp = ‘A’;
#
#
# CREATE TEMPORARY TABLE tmp_ans6 AS
#     SELECT  t1.sender ,
#             t1.recipient ,
#             COUNT(*) AS msgs
#     FROM    messages AS t1
#             INNER JOIN messages AS t2
#                 ON t1.sender = t2.recipient
#                 AND t2.sender = t1.recipient
#     -- WHERE   t1.sender = 0 or t1.sender = 181
#     GROUP BY t1.sender ,
#             t1.recipient
#     ORDER BY t1.sender, msgs DESC;
#
# SELECT  sender ,
#         recipient
# FROM
#     (SELECT  sender ,
#             recipient ,
#             RANK() OVER (PARTITION BY sender ORDER BY msgs DESC) AS _rank
#     FROM    tmp_ans6) AS x
# WHERE   _rank = 1;
#
#
# DROP table tmp_ans7;
# CREATE TEMPORARY TABLE tmp_ans7 AS
#     SELECT  t1.sender ,
#             t1.recipient ,
#             COUNT(*) AS msgs,
#             sum(length(t1.message)) as total_length
#     FROM    messages AS t1
#             INNER JOIN messages AS t2
#                 ON t1.sender = t2.recipient
#                 AND t2.sender = t1.recipient
#     GROUP BY t1.sender ,
#             t1.recipient
#     ORDER BY t1.sender, total_length DESC;
#
# CREATE TEMPORARY TABLE tmp_ans8 as
#     SELECT  sender ,
#             recipient,
#             msgs,
#             total_length
#     FROM
#         (SELECT  sender ,
#                 recipient ,
#                 msgs,
#                 total_length,
#                 RANK() OVER (PARTITION BY sender ORDER BY msgs DESC) AS msg_rank,
#                 RANK() OVER (PARTITION BY sender ORDER BY total_length DESC) AS len_rank
#         FROM    tmp_ans7) AS x
#     WHERE   len_rank = 1 or msg_rank = 1;
#
#
#        SELECT count(*) / 10
#         FROM tmp_ans8
#         WHERE sender in
#             (SELECT sender
#             from tmp_ans8
#             GROUP BY sender
#             HAVING count(*) > 1);
#
#
#
# ```

# %% [markdown]
# ## We also worked quite a lot with Jupyter Notebooks, Pandas, and Matplotlib.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
plt.style.use('fivethirtyeight')

# %%
a = np.random.randint(1000, size=50)
b = np.random.randint(1000, size=50)

# %%
a
# Out:
# array([318, 494, 891,  50, 958, 738, 484, 492,  34, 476, 933,  24, 894,
#        895, 446, 143, 623, 527, 149, 528, 294, 678, 100, 604, 829, 473,
#        586, 522, 148,  36,  19, 826,  72, 692, 335, 962, 843, 921, 589,
#        896, 254, 130, 528, 686, 494, 388, 258, 943, 230, 554])

# %%
b
# Out:
# array([948, 307, 494, 153, 587, 659, 328, 666, 385, 783, 910, 148, 549,
#        867, 784, 759, 321, 192, 705, 150, 545, 669, 308, 214, 735, 691,
#        515, 218, 232, 541, 784, 184, 987, 228, 206, 370, 945, 470, 114,
#        481, 739, 441, 831, 359, 180, 915, 539, 652, 311, 689])

# %%
fig, ax = plt.subplots(figsize=(12,8))

ax.scatter(a,b)

# %%
mask = ((a + b) % 2) == 0

# %%
fig, ax = plt.subplots(figsize=(12,8))

ax.scatter(a[mask],b[mask],color='b')
ax.scatter(a[~mask],b[~mask],color='r')

# %%
evens = a[mask]+b[mask]
evens
# Out:
# array([1266,  812, 1158,  172, 1762, 1230,  902,  944,  854,  678,  408,
#         818, 1564, 1164,  740,  380, 1010,  920, 1332, 1788,  674])

# %%
odds = a[~mask]+b[~mask]
odds
# Out:
# array([ 801, 1385,  203, 1545, 1397,  419, 1259, 1843, 1443,  719,  839,
#        1347, 1101,  577,  803, 1059,  541, 1391,  703, 1377,  993,  571,
#        1359, 1045, 1303,  797, 1595,  541, 1243])

# %%
y1 = lambda x: x*3+.05

# %%
y2 = lambda x: 5*np.sqrt(x)

# %%
fig, ax = plt.subplots(figsize=(12,8))
n = 20
ax.plot(range(0,n),[y1(n) for n in range(0,n)], 'b:*', label='linear', markersize=20)
ax.plot(range(0,n),[y2(n) for n in range(0,n)], 'r:*', label='log', markersize=20)
ax.legend()
ax.set_xscale('linear')

# %%
barheights = [3,5,1]
barlabels = ['grapes', 'oranges', 'hockey pucks']
fig, ax = plt.subplots()
ax.bar(np.arange(len(barheights)), barheights)
x_pos = np.arange(len(barheights))
ax.set_xticks(x_pos)
ax.set_xticklabels(barlabels, rotation=40)
# Out:
# [Text(0,0,'grapes'), Text(0,0,'oranges'), Text(0,0,'hockey pucks')]

# %%
barheights = [3,5,1]
barlabels = ['grapes', 'oranges', 'hockey pucks']
fig, ax = plt.subplots()
ax.bar(np.arange(len(barheights)), barheights, align='center')
x_pos = np.arange(len(barheights))
ax.set_xticks(x_pos)
ax.set_xticklabels(barlabels, rotation=45)
# Out:
# [Text(0,0,'grapes'), Text(0,0,'oranges'), Text(0,0,'hockey pucks')]

# %%
ax.bar?

# %%
fig, ax = plt.subplots(2,2, figsize=(12,8))
ax1 = ax[0,0]
ax2 = ax[0,1]
ax3 = ax[1,0]
ax4 = ax[1,1]
n = 20
ax1.plot(range(0,n),[y1(n) for n in range(0,n)], 'b:*', label='linear', markersize=20)
ax2.plot(range(0,n),[y2(n) for n in range(0,n)], 'r:*', label='log', markersize=20)
ax1.legend()
ax1.set_xscale('linear')
ax2.legend()
ax2.set_xscale('linear')

barheights = [3,5,1]
barlabels = ['grapes', 'oranges', 'hockey pucks']
ax3.bar(np.arange(len(barheights)), barheights, align='center')
x_pos = np.arange(len(barheights))
ax3.set_xticks(x_pos)
ax3.set_xticklabels(barlabels, rotation=45)

ax4.scatter(a[mask],b[mask],color='b')
ax4.scatter(a[~mask],b[~mask],color='r')

# %% [markdown]
# ## Bike Share

# %%
weather_df = pd.read_csv('data/bay_area_bikeshare/201402_weather_data_v2.csv', parse_dates=['date'], index_col='date')

# %%
weather_df.head(5)
# Out:
#             max_temperature_f  mean_temperature_f  min_temperature_f  \
# date
# 2013-08-29                 74                  68                 61
# 2013-08-30                 78                  69                 60
# 2013-08-31                 71                  64                 57
# 2013-09-01                 74                  66                 58
# 2013-09-02                 75                  69                 62
#
#             max_dew_point_f  mean_dew_point_f  min_dewpoint_f  max_humidity  \
# date
# 2013-08-29               61                58              56            93
# 2013-08-30               61                58              56            90
# 2013-08-31               57                56              54            93
# 2013-09-01               60                56              53            87
# 2013-09-02               61                60              58            93
#
#             mean_humidity  min_humidity  max_sea_level_pressure_in  ...    \
# ...

# %%
with open('data/bay_area_bikeshare/201402_weather_data_v2.csv') as f:
    labels = f.readline().strip().split(',')
[(i, label) for i, label in enumerate(labels)]
# Out:
# [(0, 'date'),
#  (1, 'max_temperature_f'),
#  (2, 'mean_temperature_f'),
#  (3, 'min_temperature_f'),
#  (4, 'max_dew_point_f'),
#  (5, 'mean_dew_point_f'),
#  (6, 'min_dewpoint_f'),
#  (7, 'max_humidity'),
#  (8, 'mean_humidity'),
#  (9, 'min_humidity'),
#  (10, 'max_sea_level_pressure_in'),
#  (11, 'mean_sea_level_pressure_in'),
#  (12, 'min_sea_level_pressure_in'),
#  (13, 'max_visibility_miles'),
#  (14, 'mean_visibility_miles'),
#  (15, 'min_visibility_miles'),
#  (16, 'max_wind_speed_m_p_h'),
#  (17, 'mean_wind_speed_m_p_h'),
#  (18, 'max_gust_speed_m_p_h'),
#  (19, 'precipitation_in'),
#  (20, 'cloud_cover'),
#  (21, 'events'),
#  (22, 'wind_dir_degrees'),
#  (23, 'zip')]

# %%
cols = [2, 5, 8, 11, 14, 17]
filepath = 'data/bay_area_bikeshare/201402_weather_data_v2.csv'
weather = np.loadtxt(filepath, delimiter=',', skiprows=1, usecols=cols)

# %%
plt.scatter(weather[:,0], weather[:,1]);

# %%
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 920 entries, 2013-08-29 to 2014-02-28
# Data columns (total 23 columns):
# max_temperature_f             920 non-null int64
# mean_temperature_f            920 non-null int64
# min_temperature_f             920 non-null int64
# max_dew_point_f               920 non-null int64
# mean_dew_point_f              920 non-null int64
# min_dewpoint_f                920 non-null int64
# max_humidity                  920 non-null int64
# mean_humidity                 920 non-null int64
# min_humidity                  920 non-null int64
# max_sea_level_pressure_in     920 non-null float64
# mean_sea_level_pressure_in    920 non-null float64
# min_sea_level_pressure_in     920 non-null float64
# max_visibility_miles          920 non-null int64
# mean_visibility_miles         920 non-null int64
# min_visibility_miles          920 non-null int64
# max_wind_speed_m_p_h          920 non-null int64
# ...

# %%
weather_df['mean_temperature_f'].hist()

# %%
weather_df.plot(kind='scatter', y='mean_temperature_f', x='cloud_cover')

# %%
weather_df.plot(kind='scatter', y='mean_temperature_f', x='mean_humidity')

# %%
weather_df.plot(kind='scatter', y='mean_temperature_f', x='mean_sea_level_pressure_in')

# %%
sns.jointplot(data=weather_df, x='mean_sea_level_pressure_in', y='mean_temperature_f', size=10)
# Out:
# /Users/jeremymiller/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
weather_df['mean_temperature_f'].plot(figsize=(14,8), marker='o')
weather_df['mean_humidity'].plot(figsize=(12,8), marker = 'o')

# %%
weather_df.columns
# Out:
# Index(['max_temperature_f', 'mean_temperature_f', 'min_temperature_f',
#        'max_dew_point_f', 'mean_dew_point_f', 'min_dewpoint_f', 'max_humidity',
#        'mean_humidity', 'min_humidity', 'max_sea_level_pressure_in',
#        'mean_sea_level_pressure_in', 'min_sea_level_pressure_in',
#        'max_visibility_miles', 'mean_visibility_miles', 'min_visibility_miles',
#        'max_wind_speed_m_p_h', 'mean_wind_speed_m_p_h', 'max_gust_speed_m_p_h',
#        'precipitation_in', 'cloud_cover', 'events', 'wind_dir_degrees', 'zip'],
#       dtype='object')

# %%
plt.hist(x=weather_df['cloud_cover'], bins=20)
# Out:
# (array([356.,   0., 112.,   0.,   0.,  95.,   0., 101.,   0.,   0.,  87.,
#           0.,  72.,   0.,   0.,  35.,   0.,  47.,   0.,  15.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. , 4.4, 4.8,
#         5.2, 5.6, 6. , 6.4, 6.8, 7.2, 7.6, 8. ]),
#  <a list of 20 Patch objects>)

# %%
tripdf = pd.read_csv('data/bay_area_bikeshare/201402_trip_data_v2.csv', parse_dates=['start_date', 'end_date'], index_col= 'trip_id')

# %%
stationdf = pd.read_csv('data/bay_area_bikeshare/201402_station_data_v2.csv', parse_dates=['installation'], index_col='station_id')

# %%
tripdf.sample(10)
# Out:
#          duration          start_date  \
# trip_id
# 84853         417 2013-11-05 19:07:00
# 122317       1109 2013-12-11 18:09:00
# 179759        623 2014-02-10 16:34:00
# 165196       1074 2014-01-24 17:56:00
# 41530        1038 2013-10-01 12:24:00
# 12910         569 2013-09-06 19:14:00
# 164009        289 2014-01-23 19:28:00
# 14371        1596 2013-09-08 10:49:00
# 41862         574 2013-10-01 16:54:00
# 169417        362 2014-01-29 08:01:00
#
#                                     start_station  start_terminal  \
# trip_id
# 84853                             2nd at Townsend              61
# 122317                            2nd at Townsend              61
# 179759                   South Van Ness at Market              66
# 165196                     SJSU 4th at San Carlos              12
# 41530                             2nd at Townsend              61
# 12910                           2nd at South Park              64
# ...

# %%
stationdf.sample(10)
# Out:
#                                 name        lat        long  dockcount  \
# station_id
# 8                San Salvador at 1st  37.330165 -121.885831         15
# 62                     2nd at Folsom  37.785299 -122.396236         19
# 58           San Francisco City Hall  37.778650 -122.418235         19
# 59               Golden Gate at Polk  37.781332 -122.418603         23
# 45          Commercial at Montgomery  37.794231 -122.402923         15
# 49                   Spear at Folsom  37.789625 -122.390264         19
# 12            SJSU 4th at San Carlos  37.332808 -121.883891         19
# 77                 Market at Sansome  37.789625 -122.400811         27
# 61                   2nd at Townsend  37.780526 -122.390288         27
# 76                     Market at 4th  37.786305 -122.404966         19
#
#                  landmark installation
# station_id
# 8                San Jose   2013-08-05
# 62          San Francisco   2013-08-22
# 58          San Francisco   2013-08-21
# ...

# %%
plt.scatter(x=tripdf['start_terminal'], y=tripdf['end_terminal'])

# %%
plt.figure(figsize=(8,12))
plt.scatter(y=stationdf['lat'], x=stationdf['long'])
